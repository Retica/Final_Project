# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf
import os
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd

hpi_df = pd.read_csv("../data_csv/clean_hpi_master_ave1.csv")
hpi_df.head(10)
# Out:
#      yr    index_sa
# 0  1991  100.347444
# 1  1992  102.726194
# 2  1993  105.367898
# 3  1994  109.412349
# 4  1995  112.551794
# 5  1996  116.042849
# 6  1997  119.525865
# 7  1998  125.297532
# 8  1999  133.079484
# 9  2000  142.485214

# %%
#get the unique values
hpi_df.nunique()
# Out:
# yr          32
# index_sa    32
# dtype: int64

# %%
# Generate our categorical variable lists
hpi_cat = hpi_df.dtypes[hpi_df.dtypes == "object"].index.tolist()

# %%
# Create a OneHotEncoder instance
enc = OneHotEncoder(sparse=False)

# Fit and transform the OneHotEncoder using the categorical variable list
encode_df = pd.DataFrame(enc.fit_transform(hpi_df[hpi_cat]))

# Add the encoded variable names to the dataframe
encode_df.columns = enc.get_feature_names(hpi_cat)
encode_df.head()
# Out:
# C:\Users\renee\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
# Merge one-hot encoded features and drop the originals
hpi_df = hpi_df.merge(encode_df,left_index=True, right_index=True)
hpi_df = hpi_df.drop(hpi_cat,1)
hpi_df.head()

# %%
y = hpi_df
X = hpi_df.index_sa


# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [60], in <cell line: 1>()
# ----> 1 y = hpi_df.columns()
#       2 X = hpi_df.index_sa
#       5 # Split the preprocessed data into a training and testing dataset
#
# TypeError: 'Index' object is not callable

# %%
# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the logistic regression model
log_classifier = LogisticRegression(solver="lbfgs",max_iter=200)

# Train the model
log_classifier.fit(X_train,y_train)

# Evaluate the model
y_pred = log_classifier.predict(X_test)
print(f" Logistic regression model accuracy: {accuracy_score(y_test,y_pred):.3f}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [57], in <cell line: 5>()
#       2 log_classifier = LogisticRegression(solver="lbfgs",max_iter=200)
#       4 # Train the model
# ----> 5 log_classifier.fit(X_train,y_train)
#       7 # Evaluate the model
#       8 y_pred = log_classifier.predict(X_test)
#
# File ~\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:1516, in LogisticRegression.fit(self, X, y, sample_weight)
#    1506     _dtype = [np.float64, np.float32]
#    1508 X, y = self._validate_data(
#    1509     X,
#    1510     y,
#    (...)
#    1514     accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1515 )
# -> 1516 check_classification_targets(y)
#    1517 self.classes_ = np.unique(y)
#    1519 multi_class = _check_multi_class(self.multi_class, solver, len(self.classes_))
#
# File ~\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\multiclass.py:197, in check_classification_targets(y)
#     189 y_type = type_of_target(y)
#     190 if y_type not in [
#     191     "binary",
#     192     "multiclass",
#    (...)
#     195     "multilabel-sequences",
#     196 ]:
# --> 197     raise ValueError("Unknown label type: %r" % y_type)
#
# ValueError: Unknown label type: 'continuous'

# %%
# Define the checkpoint path and filenames
os.makedirs("checkpoints/",exist_ok=True)
checkpoint_path = "checkpoints/weights.{epoch:02d}.hdf5"

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 450ms/step - loss: 38.7890 - accuracy: 0.0000e+00
# Epoch 2/100
# 1/1 [==============================] - 0s 4ms/step - loss: 31.0253 - accuracy: 0.0000e+00
# Epoch 3/100
# 1/1 [==============================] - 0s 4ms/step - loss: 23.5500 - accuracy: 0.0000e+00
# Epoch 4/100
# 1/1 [==============================] - 0s 3ms/step - loss: 16.2403 - accuracy: 0.0000e+00
# Epoch 5/100
# 1/1 [==============================] - 0s 3ms/step - loss: 9.2099 - accuracy: 0.0000e+00
# Epoch 6/100
# 1/1 [==============================] - 0s 5ms/step - loss: 2.5041 - accuracy: 0.0000e+00
# Epoch 7/100
# 1/1 [==============================] - 0s 3ms/step - loss: -3.8524 - accuracy: 0.0000e+00
# Epoch 8/100
# 1/1 [==============================] - 0s 3ms/step - loss: -9.8350 - accuracy: 0.0000e+00
# Epoch 9/100
# 1/1 [==============================] - 0s 3ms/step - loss: -15.3689 - accuracy: 0.0000e+00
# Epoch 10/100
# 1/1 [==============================] - 0s 4ms/step - loss: -20.4549 - accuracy: 0.0000e+00
# Epoch 11/100
# 1/1 [==============================] - 0s 3ms/step - loss: -25.2692 - accuracy: 0.0000e+00
# Epoch 12/100
# 1/1 [==============================] - 0s 3ms/step - loss: -29.8033 - accuracy: 0.0000e+00
# Epoch 13/100
# 1/1 [==============================] - 0s 4ms/step - loss: -34.1612 - accuracy: 0.0000e+00
# Epoch 14/100
# 1/1 [==============================] - 0s 3ms/step - loss: -38.4456 - accuracy: 0.0000e+00
# Epoch 15/100
# 1/1 [==============================] - 0s 3ms/step - loss: -42.5689 - accuracy: 0.0000e+00
# Epoch 16/100
# 1/1 [==============================] - 0s 4ms/step - loss: -46.6701 - accuracy: 0.0000e+00
# Epoch 17/100
# 1/1 [==============================] - 0s 3ms/step - loss: -50.7245 - accuracy: 0.0000e+00
# Epoch 18/100
# 1/1 [==============================] - 0s 3ms/step - loss: -54.7159 - accuracy: 0.0000e+00
# Epoch 19/100
# 1/1 [==============================] - 0s 5ms/step - loss: -58.5964 - accuracy: 0.0000e+00
# Epoch 20/100
# 1/1 [==============================] - 0s 3ms/step - loss: -62.4490 - accuracy: 0.0000e+00
# Epoch 21/100
# 1/1 [==============================] - 0s 3ms/step - loss: -66.2931 - accuracy: 0.0000e+00
# Epoch 22/100
# 1/1 [==============================] - 0s 5ms/step - loss: -70.1473 - accuracy: 0.0000e+00
# Epoch 23/100
# 1/1 [==============================] - 0s 5ms/step - loss: -74.0778 - accuracy: 0.0000e+00
# Epoch 24/100
# 1/1 [==============================] - 0s 5ms/step - loss: -78.0899 - accuracy: 0.0000e+00
# Epoch 25/100
# 1/1 [==============================] - 0s 3ms/step - loss: -82.1908 - accuracy: 0.0000e+00
# Epoch 26/100
# 1/1 [==============================] - 0s 3ms/step - loss: -86.3972 - accuracy: 0.0000e+00
# Epoch 27/100
# 1/1 [==============================] - 0s 4ms/step - loss: -90.7045 - accuracy: 0.0000e+00
# Epoch 28/100
# 1/1 [==============================] - 0s 3ms/step - loss: -95.1133 - accuracy: 0.0000e+00
# Epoch 29/100
# 1/1 [==============================] - 0s 2ms/step - loss: -99.6379 - accuracy: 0.0000e+00
# Epoch 30/100
# 1/1 [==============================] - 0s 5ms/step - loss: -104.3013 - accuracy: 0.0000e+00
# Epoch 31/100
# 1/1 [==============================] - 0s 3ms/step - loss: -109.0847 - accuracy: 0.0000e+00
# Epoch 32/100
# 1/1 [==============================] - 0s 4ms/step - loss: -113.9905 - accuracy: 0.0000e+00
# Epoch 33/100
# 1/1 [==============================] - 0s 3ms/step - loss: -119.0230 - accuracy: 0.0000e+00
# Epoch 34/100
# 1/1 [==============================] - 0s 3ms/step - loss: -124.1788 - accuracy: 0.0000e+00
# Epoch 35/100
# 1/1 [==============================] - 0s 2ms/step - loss: -129.4693 - accuracy: 0.0000e+00
# Epoch 36/100
# 1/1 [==============================] - 0s 3ms/step - loss: -134.8923 - accuracy: 0.0000e+00
# Epoch 37/100
# 1/1 [==============================] - 0s 3ms/step - loss: -140.4695 - accuracy: 0.0000e+00
# Epoch 38/100
# 1/1 [==============================] - 0s 3ms/step - loss: -146.1990 - accuracy: 0.0000e+00
# Epoch 39/100
# 1/1 [==============================] - 0s 4ms/step - loss: -152.0901 - accuracy: 0.0000e+00
# Epoch 40/100
# 1/1 [==============================] - 0s 4ms/step - loss: -158.1491 - accuracy: 0.0000e+00
# Epoch 41/100
# 1/1 [==============================] - 0s 4ms/step - loss: -164.3759 - accuracy: 0.0000e+00
# Epoch 42/100
# 1/1 [==============================] - 0s 2ms/step - loss: -170.7762 - accuracy: 0.0000e+00
# Epoch 43/100
# 1/1 [==============================] - 0s 4ms/step - loss: -177.3609 - accuracy: 0.0000e+00
# Epoch 44/100
# 1/1 [==============================] - 0s 3ms/step - loss: -184.1362 - accuracy: 0.0000e+00
# Epoch 45/100
# 1/1 [==============================] - 0s 3ms/step - loss: -191.1191 - accuracy: 0.0000e+00
# Epoch 46/100
# 1/1 [==============================] - 0s 4ms/step - loss: -198.3157 - accuracy: 0.0000e+00
# Epoch 47/100
# 1/1 [==============================] - 0s 3ms/step - loss: -205.7376 - accuracy: 0.0000e+00
# Epoch 48/100
# 1/1 [==============================] - 0s 3ms/step - loss: -213.3913 - accuracy: 0.0000e+00
# Epoch 49/100
# 1/1 [==============================] - 0s 3ms/step - loss: -221.2841 - accuracy: 0.0000e+00
# Epoch 50/100
# 1/1 [==============================] - 0s 3ms/step - loss: -229.4252 - accuracy: 0.0000e+00
# Epoch 51/100
# 1/1 [==============================] - 0s 3ms/step - loss: -237.8197 - accuracy: 0.0000e+00
# Epoch 52/100
# 1/1 [==============================] - 0s 3ms/step - loss: -246.4759 - accuracy: 0.0000e+00
# Epoch 53/100
# 1/1 [==============================] - 0s 3ms/step - loss: -255.4039 - accuracy: 0.0000e+00
# Epoch 54/100
# 1/1 [==============================] - 0s 3ms/step - loss: -264.6084 - accuracy: 0.0000e+00
# Epoch 55/100
# 1/1 [==============================] - 0s 3ms/step - loss: -274.0970 - accuracy: 0.0000e+00
# Epoch 56/100
# 1/1 [==============================] - 0s 2ms/step - loss: -283.8805 - accuracy: 0.0000e+00
# Epoch 57/100
# 1/1 [==============================] - 0s 3ms/step - loss: -293.9669 - accuracy: 0.0000e+00
# Epoch 58/100
# 1/1 [==============================] - 0s 3ms/step - loss: -304.3705 - accuracy: 0.0000e+00
# Epoch 59/100
# 1/1 [==============================] - 0s 4ms/step - loss: -315.0973 - accuracy: 0.0000e+00
# Epoch 60/100
# 1/1 [==============================] - 0s 3ms/step - loss: -326.1651 - accuracy: 0.0000e+00
# Epoch 61/100
# 1/1 [==============================] - 0s 3ms/step - loss: -337.5713 - accuracy: 0.0000e+00
# Epoch 62/100
# 1/1 [==============================] - 0s 4ms/step - loss: -349.3224 - accuracy: 0.0000e+00
# Epoch 63/100
# 1/1 [==============================] - 0s 3ms/step - loss: -361.4194 - accuracy: 0.0000e+00
# Epoch 64/100
# 1/1 [==============================] - 0s 3ms/step - loss: -373.8690 - accuracy: 0.0000e+00
# Epoch 65/100
# 1/1 [==============================] - 0s 3ms/step - loss: -386.6696 - accuracy: 0.0000e+00
# Epoch 66/100
# 1/1 [==============================] - 0s 3ms/step - loss: -399.8294 - accuracy: 0.0000e+00
# Epoch 67/100
# 1/1 [==============================] - 0s 4ms/step - loss: -413.3640 - accuracy: 0.0000e+00
# Epoch 68/100
# 1/1 [==============================] - 0s 2ms/step - loss: -427.2988 - accuracy: 0.0000e+00
# Epoch 69/100
# 1/1 [==============================] - 0s 4ms/step - loss: -441.6384 - accuracy: 0.0000e+00
# Epoch 70/100
# 1/1 [==============================] - 0s 3ms/step - loss: -456.3982 - accuracy: 0.0000e+00
# Epoch 71/100
# 1/1 [==============================] - 0s 2ms/step - loss: -471.5849 - accuracy: 0.0000e+00
# Epoch 72/100
# 1/1 [==============================] - 0s 4ms/step - loss: -487.2113 - accuracy: 0.0000e+00
# Epoch 73/100
# 1/1 [==============================] - 0s 2ms/step - loss: -503.2859 - accuracy: 0.0000e+00
# Epoch 74/100
# 1/1 [==============================] - 0s 2ms/step - loss: -519.8135 - accuracy: 0.0000e+00
# Epoch 75/100
# 1/1 [==============================] - 0s 3ms/step - loss: -536.8032 - accuracy: 0.0000e+00
# Epoch 76/100
# 1/1 [==============================] - 0s 4ms/step - loss: -554.2635 - accuracy: 0.0000e+00
# Epoch 77/100
# 1/1 [==============================] - 0s 2ms/step - loss: -572.2076 - accuracy: 0.0000e+00
# Epoch 78/100
# 1/1 [==============================] - 0s 2ms/step - loss: -590.6491 - accuracy: 0.0000e+00
# Epoch 79/100
# 1/1 [==============================] - 0s 3ms/step - loss: -609.5947 - accuracy: 0.0000e+00
# Epoch 80/100
# 1/1 [==============================] - 0s 3ms/step - loss: -629.0534 - accuracy: 0.0000e+00
# Epoch 81/100
# 1/1 [==============================] - 0s 4ms/step - loss: -649.0472 - accuracy: 0.0000e+00
# Epoch 82/100
# 1/1 [==============================] - 0s 4ms/step - loss: -669.5817 - accuracy: 0.0000e+00
# Epoch 83/100
# 1/1 [==============================] - 0s 2ms/step - loss: -690.6597 - accuracy: 0.0000e+00
# Epoch 84/100
# 1/1 [==============================] - 0s 3ms/step - loss: -712.3029 - accuracy: 0.0000e+00
# Epoch 85/100
# 1/1 [==============================] - 0s 3ms/step - loss: -734.5197 - accuracy: 0.0000e+00
# Epoch 86/100
# 1/1 [==============================] - 0s 3ms/step - loss: -757.3196 - accuracy: 0.0000e+00
# Epoch 87/100
# 1/1 [==============================] - 0s 2ms/step - loss: -780.7133 - accuracy: 0.0000e+00
# Epoch 88/100
# 1/1 [==============================] - 0s 4ms/step - loss: -804.7148 - accuracy: 0.0000e+00
# Epoch 89/100
# 1/1 [==============================] - 0s 2ms/step - loss: -829.3337 - accuracy: 0.0000e+00
# Epoch 90/100
# 1/1 [==============================] - 0s 2ms/step - loss: -854.5801 - accuracy: 0.0000e+00
# Epoch 91/100
# 1/1 [==============================] - 0s 3ms/step - loss: -880.4654 - accuracy: 0.0000e+00
# Epoch 92/100
# 1/1 [==============================] - 0s 3ms/step - loss: -907.0020 - accuracy: 0.0000e+00
# Epoch 93/100
# 1/1 [==============================] - 0s 3ms/step - loss: -934.2012 - accuracy: 0.0000e+00
# Epoch 94/100
# 1/1 [==============================] - 0s 4ms/step - loss: -962.0752 - accuracy: 0.0000e+00
# Epoch 95/100
# 1/1 [==============================] - 0s 3ms/step - loss: -990.6325 - accuracy: 0.0000e+00
# Epoch 96/100
# 1/1 [==============================] - 0s 3ms/step - loss: -1019.8835 - accuracy: 0.0000e+00
# Epoch 97/100
# 1/1 [==============================] - 0s 3ms/step - loss: -1049.8390 - accuracy: 0.0000e+00
# Epoch 98/100
# 1/1 [==============================] - 0s 4ms/step - loss: -1080.5238 - accuracy: 0.0000e+00
# Epoch 99/100
# 1/1 [==============================] - 0s 3ms/step - loss: -1111.9409 - accuracy: 0.0000e+00
# Epoch 100/100
# 1/1 [==============================] - 0s 3ms/step - loss: -1144.1058 - accuracy: 0.0000e+00
