# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import hvplot.pandas

# %%
# Load data
file_path = "../data_csv/clean_1991_df.csv"
df_1991 = pd.read_csv(file_path)
df_1991.head(10)
# Out:
#    Unnamed: 0     hpi_type hpi_flavor               frequency  \
# 0           0  traditional    monthly  USA or Census Division
# 1           1  traditional    monthly  USA or Census Division
# 2           2  traditional    monthly  USA or Census Division
# 3           3  traditional    monthly  USA or Census Division
# 4           4  traditional    monthly  USA or Census Division
# 5           5  traditional    monthly  USA or Census Division
# 6           6  traditional    monthly  USA or Census Division
# 7           7  traditional    monthly  USA or Census Division
# 8           8  traditional    monthly  USA or Census Division
# 9           9  traditional    monthly  USA or Census Division
#
#                          level place_name  place_id             yr  period  \
# 0  East North Central Division     DV_ENC      1991  purchase-only       1
# 1  East North Central Division     DV_ENC      1991  purchase-only       2
# ...

# %%
print(df_1991.dtypes)
# Out:
# Unnamed: 0      int64
# hpi_type       object
# hpi_flavor     object
# frequency      object
# level          object
# place_name     object
# place_id        int64
# yr             object
# period          int64
# index_nsa     float64
# index_sa      float64
# dtype: object

# %%
# Drop the non-beneficial ID columns
df_1991 = df_1991.drop(columns = ['Unnamed: 0','hpi_type'], axis= 1)
df_1991.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [20], in <cell line: 2>()
#       1 # Drop the non-beneficial ID columns
# ----> 2 df_1991 = df_1991.drop(columns = ['Unnamed: 0','hpi_type'], axis= 1)
#       3 df_1991.head()
#
# File ~\anaconda3\envs\PythonData\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:4948, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
encode_1991 = pd.get_dummies(df_1991, columns = ['hpi_flavor','frequency', 'level', 'place_name', 'yr'])

# %%
#standardize data with standardscaler
scaled_1991 = StandardScaler().fit_transform(df_1991)
print(scaled_1991[0:5])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [18], in <cell line: 2>()
#       1 #standardize data with standardscaler
# ----> 2 scaled_1991 = StandardScaler().fit_transform(df_1991)
#       3 print(scaled_1991[0:5])
#
# File ~\anaconda3\envs\PythonData\lib\site-packages\sklearn\base.py:852, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     848 # non-optimized default implementation; override when a better
#     849 # method is possible for a given clustering algorithm
#     850 if y is None:
#     851     # fit method of arity 1 (unsupervised transformation)
# --> 852     return self.fit(X, **fit_params).transform(X)
#     853 else:
#     854     # fit method of arity 2 (supervised transformation)
#     855     return self.fit(X, y, **fit_params).transform(X)
#
# ...
